# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Train a Vision Transformer on small datasets

# %%
# !pip install tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 31.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
import math
import numpy as np
import tensorflow as tf
from tensorflow import keras
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# Setting seed for reproducibiltiy
SEED = 42
keras.utils.set_random_seed(SEED)

# %% [markdown]
# ## Prepare the data

# %%
NUM_CLASSES = 100
INPUT_SHAPE = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 14s 0us/step
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %% [markdown]
# ## Configure the hyperparameters
#
# The hyperparameters are different from the paper. Feel free to tune
# the hyperparameters yourself.

# %%
# DATA
BUFFER_SIZE = 512 # Double of batch size usually
BATCH_SIZE = 256 # 128 in paper

# AUGMENTATION
IMAGE_SIZE = 72 # We'll resize input images to this size
PATCH_SIZE = 6 # Set to 8 in paper, Size of the patches to be extract from the input images
NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2

# OPTIMIZER
LEARNING_RATE = 0.001 # 0.003 in paper
WEIGHT_DECAY = 0.0001

# TRAINING
EPOCHS = 50 # Set to 100 in paper

# ARCHITECTURE
LAYER_NORM_EPS = 1e-6
TRANSFORMER_LAYERS = 8 # Depth was 9 in paper
PROJECTION_DIM = 64 # hidden dimention is 192
NUM_HEADS = 4 # 12 in paper
TRANSFORMER_UNITS = [
    PROJECTION_DIM * 2, # Encoder MLP dimension is TRANSFORMER_UNITS
    PROJECTION_DIM,
]
MLP_HEAD_UNITS = [2048, 1024] # Size of last MLP

# %% [markdown]
# ## Use data augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %% [markdown]
# ## Implement Shifted Patch Tokenization

# %%
class ShiftedPatchTokenization(layers.Layer):
    def __init__(
        self,
        image_size=IMAGE_SIZE,
        patch_size=PATCH_SIZE,
        num_patches=NUM_PATCHES,
        projection_dim=PROJECTION_DIM,
        vanilla=False,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.vanilla = vanilla  # Flag to swtich to vanilla patch extractor
        self.image_size = image_size
        self.patch_size = patch_size
        self.half_patch = patch_size // 2
        self.flatten_patches = layers.Reshape((num_patches, -1))
        self.projection = layers.Dense(units=projection_dim)
        self.layer_norm = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)

    def crop_shift_pad(self, images, mode):
        # Build the diagonally shifted images
        if mode == "left-up":
            crop_height = self.half_patch
            crop_width = self.half_patch
            shift_height = 0
            shift_width = 0
        elif mode == "left-down":
            crop_height = 0
            crop_width = self.half_patch
            shift_height = self.half_patch
            shift_width = 0
        elif mode == "right-up":
            crop_height = self.half_patch
            crop_width = 0
            shift_height = 0
            shift_width = self.half_patch
        else:
            crop_height = 0
            crop_width = 0
            shift_height = self.half_patch
            shift_width = self.half_patch

        # Crop the shifted images and pad them
        crop = tf.image.crop_to_bounding_box(
            images,
            offset_height=crop_height,
            offset_width=crop_width,
            target_height=self.image_size - self.half_patch,
            target_width=self.image_size - self.half_patch,
        )
        shift_pad = tf.image.pad_to_bounding_box(
            crop,
            offset_height=shift_height,
            offset_width=shift_width,
            target_height=self.image_size,
            target_width=self.image_size,
        )
        return shift_pad

    def call(self, images):
        if not self.vanilla:
            # Concat the shifted images with the original image
            images = tf.concat(
                [
                    images,
                    self.crop_shift_pad(images, mode="left-up"),
                    self.crop_shift_pad(images, mode="left-down"),
                    self.crop_shift_pad(images, mode="right-up"),
                    self.crop_shift_pad(images, mode="right-down"),
                ],
                axis=-1,
            )
        # Patchify the images and flatten it
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        flat_patches = self.flatten_patches(patches)
        if not self.vanilla:
            # Layer normalize the flat patches and linearly project it
            tokens = self.layer_norm(flat_patches)
            tokens = self.projection(tokens)
        else:
            # Linearly project the flat patches
            tokens = self.projection(flat_patches)
        return (tokens, patches)

# %% [markdown]
# ### Visualize the patches

# %%
# Get a random image from the training dataset
# and resize the image
image = x_train[np.random.choice(range(x_train.shape[0]))]
resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(IMAGE_SIZE, IMAGE_SIZE)
)

# Vanilla patch maker: This takes an image and divides into
# patches as in the original ViT paper
(token, patch) = ShiftedPatchTokenization(vanilla=True)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
count = 1
plt.figure(figsize=(4, 4))
for row in range(n):
    for col in range(n):
        plt.subplot(n, n, count)
        count = count + 1
        image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 3))
        plt.imshow(image)
        plt.axis("off")
plt.show()

# Shifted Patch Tokenization: This layer takes the image, shifts it
# diagonally and then extracts patches from the concatinated images
(token, patch) = ShiftedPatchTokenization(vanilla=False)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
shifted_images = ["ORIGINAL", "LEFT-UP", "LEFT-DOWN", "RIGHT-UP", "RIGHT-DOWN"]
for index, name in enumerate(shifted_images):
    print(name)
    count = 1
    plt.figure(figsize=(4, 4))
    for row in range(n):
        for col in range(n):
            plt.subplot(n, n, count)
            count = count + 1
            image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 5 * 3))
            plt.imshow(image[..., 3 * index : 3 * index + 3])
            plt.axis("off")
    plt.show()
# Out:
# ORIGINAL
# LEFT-UP
# LEFT-DOWN
# RIGHT-UP
# RIGHT-DOWN

# %% [markdown]
# ## Implement the patch encoding layer
#
# This layer accepts projected patches and then adds positional
# information to them.

# %%
class PatchEncoder(layers.Layer):
    def __init__(
        self, num_patches=NUM_PATCHES, projection_dim=PROJECTION_DIM, **kwargs
    ):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        self.positions = tf.range(start=0, limit=self.num_patches, delta=1)

    def call(self, encoded_patches):
        encoded_positions = self.position_embedding(self.positions)
        encoded_patches = encoded_patches + encoded_positions
        return encoded_patches

# %% [markdown]
# ## Implement Locality Self Attention
#
# The regular attention equation is stated below.
#
# | ![Equation of attention](https://miro.medium.com/max/396/1*P9sV1xXM10t943bXy_G9yg.png) |
# | :--: |
# | [Source](https://towardsdatascience.com/attention-is-all-you-need-discovering-the-transformer-paper-73e5ff5e0634) |
#
# The attention module takes a query, key, and value. First, we compute the
# similarity between the query and key via a dot product. Then, the result
# is scaled by the square root of the key dimension. The scaling prevents
# the softmax function from having an overly small gradient. Softmax is then
# applied to the scaled dot product to produce the attention weights.
# The value is then modulated via the attention weights.
#
# In self-attention, query, key and value come from the same input.
# The dot product would result in large self-token relations rather than
# inter-token relations. This also means that the softmax gives higher
# probabilities to self-token relations than the inter-token relations.
# To combat this, the authors propose masking the diagonal of the dot product.
# This way, we force the attention module to pay more attention to the
# inter-token relations.
#
# The scaling factor is a constant in the regular attention module.
# This acts like a temperature term that can modulate the softmax function.
# The authors suggest a learnable temperature term instead of a constant.
#
# | ![Implementation of LSA](https://i.imgur.com/GTV99pk.png) |
# | :--: |
# | Locality Self Attention [Source](https://arxiv.org/abs/2112.13492v1) |
#
# The above two pointers make the Locality Self Attention. We have subclassed the
# [`layers.MultiHeadAttention`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MultiHeadAttention)
# and implemented the trainable temperature. The attention mask is built
# at a later stage.

# %%
class MultiHeadAttentionLSA(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # The trainable temperature term. The initial value is
        # the square root of the key dimension.
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores

# %% [markdown]
# ## Implement the MLP

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


# Build the diagonal attention mask
diag_attn_mask = 1 - tf.eye(NUM_PATCHES)
diag_attn_mask = tf.cast([diag_attn_mask], dtype=tf.int8)

# %% [markdown]
# ## Build the ViT

# %%
def create_vit_classifier(vanilla=False):
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    (tokens, _) = ShiftedPatchTokenization(vanilla=vanilla)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder()(tokens)

    # Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        if not vanilla:
            attention_output = MultiHeadAttentionLSA(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1, attention_mask=diag_attn_mask)
        else:
            attention_output = layers.MultiHeadAttention(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %% [markdown]
# ## Compile, train, and evaluate the mode

# %%
# Some code is taken from:
# https://www.kaggle.com/ashusma/training-rfcx-tensorflow-tpu-effnet-b2.
class WarmUpCosine(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")

        cos_annealed_lr = tf.cos(
            self.pi
            * (tf.cast(step, tf.float32) - self.warmup_steps)
            / float(self.total_steps - self.warmup_steps)
        )
        learning_rate = 0.5 * self.learning_rate_base * (1 + cos_annealed_lr)

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )


def run_experiment(model):
    total_steps = int((len(x_train) / BATCH_SIZE) * EPOCHS)
    warmup_epoch_percentage = 0.10
    warmup_steps = int(total_steps * warmup_epoch_percentage)
    scheduled_lrs = WarmUpCosine(
        learning_rate_base=LEARNING_RATE,
        total_steps=total_steps,
        warmup_learning_rate=0.0,
        warmup_steps=warmup_steps,
    )

    optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_split=0.1,
    )
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


# Run experiments with the vanilla ViT
vit = create_vit_classifier(vanilla=True)
history = run_experiment(vit)

# Run experiments with the Shifted Patch Tokenization and
# Locality Self Attention modified ViT
vit_sl = create_vit_classifier(vanilla=False)
history = run_experiment(vit_sl)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 99s 504ms/step - loss: 4.4864 - accuracy: 0.0433 - top-5-accuracy: 0.1551 - val_loss: 3.9355 - val_accuracy: 0.1052 - val_top-5-accuracy: 0.3086
# Epoch 2/50
# 176/176 [==============================] - 85s 483ms/step - loss: 3.9431 - accuracy: 0.0953 - top-5-accuracy: 0.2900 - val_loss: 3.5852 - val_accuracy: 0.1558 - val_top-5-accuracy: 0.4070
# Epoch 3/50
# 176/176 [==============================] - 85s 481ms/step - loss: 3.6782 - accuracy: 0.1339 - top-5-accuracy: 0.3701 - val_loss: 3.3304 - val_accuracy: 0.2004 - val_top-5-accuracy: 0.4736
# Epoch 4/50
# 176/176 [==============================] - 85s 483ms/step - loss: 3.5062 - accuracy: 0.1603 - top-5-accuracy: 0.4207 - val_loss: 3.2188 - val_accuracy: 0.2226 - val_top-5-accuracy: 0.5058
# Epoch 5/50
# 176/176 [==============================] - 84s 477ms/step - loss: 3.3468 - accuracy: 0.1894 - top-5-accuracy: 0.4639 - val_loss: 3.0306 - val_accuracy: 0.2592 - val_top-5-accuracy: 0.5552
# Epoch 6/50
# 176/176 [==============================] - 85s 482ms/step - loss: 3.2104 - accuracy: 0.2159 - top-5-accuracy: 0.5014 - val_loss: 2.9570 - val_accuracy: 0.2734 - val_top-5-accuracy: 0.5708
# Epoch 7/50
# 176/176 [==============================] - 84s 477ms/step - loss: 3.0760 - accuracy: 0.2419 - top-5-accuracy: 0.5359 - val_loss: 2.8075 - val_accuracy: 0.3006 - val_top-5-accuracy: 0.6064
# Epoch 8/50
# 176/176 [==============================] - 85s 482ms/step - loss: 2.9607 - accuracy: 0.2636 - top-5-accuracy: 0.5668 - val_loss: 2.7043 - val_accuracy: 0.3248 - val_top-5-accuracy: 0.6298
# Epoch 9/50
# 176/176 [==============================] - 84s 477ms/step - loss: 2.8431 - accuracy: 0.2906 - top-5-accuracy: 0.5938 - val_loss: 2.6489 - val_accuracy: 0.3294 - val_top-5-accuracy: 0.6380
# Epoch 10/50
# 176/176 [==============================] - 85s 480ms/step - loss: 2.7639 - accuracy: 0.3014 - top-5-accuracy: 0.6118 - val_loss: 2.5289 - val_accuracy: 0.3502 - val_top-5-accuracy: 0.6664
# Epoch 11/50
# 176/176 [==============================] - 84s 476ms/step - loss: 2.6708 - accuracy: 0.3197 - top-5-accuracy: 0.6356 - val_loss: 2.4648 - val_accuracy: 0.3718 - val_top-5-accuracy: 0.6742
# Epoch 12/50
# 176/176 [==============================] - 84s 480ms/step - loss: 2.5844 - accuracy: 0.3404 - top-5-accuracy: 0.6539 - val_loss: 2.4320 - val_accuracy: 0.3812 - val_top-5-accuracy: 0.6840
# Epoch 13/50
# 176/176 [==============================] - 84s 476ms/step - loss: 2.5070 - accuracy: 0.3551 - top-5-accuracy: 0.6706 - val_loss: 2.3381 - val_accuracy: 0.4044 - val_top-5-accuracy: 0.6992
# Epoch 14/50
# 176/176 [==============================] - 85s 481ms/step - loss: 2.4272 - accuracy: 0.3722 - top-5-accuracy: 0.6896 - val_loss: 2.3518 - val_accuracy: 0.4000 - val_top-5-accuracy: 0.6934
# Epoch 15/50
# 176/176 [==============================] - 84s 475ms/step - loss: 2.3685 - accuracy: 0.3829 - top-5-accuracy: 0.6988 - val_loss: 2.2636 - val_accuracy: 0.4176 - val_top-5-accuracy: 0.7182
# Epoch 16/50
# 176/176 [==============================] - 85s 480ms/step - loss: 2.3041 - accuracy: 0.3975 - top-5-accuracy: 0.7119 - val_loss: 2.1960 - val_accuracy: 0.4310 - val_top-5-accuracy: 0.7290
# Epoch 17/50
# 176/176 [==============================] - 84s 477ms/step - loss: 2.2466 - accuracy: 0.4110 - top-5-accuracy: 0.7282 - val_loss: 2.1908 - val_accuracy: 0.4302 - val_top-5-accuracy: 0.7344
# Epoch 18/50
# 176/176 [==============================] - 84s 480ms/step - loss: 2.1884 - accuracy: 0.4208 - top-5-accuracy: 0.7368 - val_loss: 2.1706 - val_accuracy: 0.4362 - val_top-5-accuracy: 0.7376
# Epoch 19/50
# 176/176 [==============================] - 84s 476ms/step - loss: 2.1348 - accuracy: 0.4315 - top-5-accuracy: 0.7468 - val_loss: 2.1366 - val_accuracy: 0.4468 - val_top-5-accuracy: 0.7422
# Epoch 20/50
# 176/176 [==============================] - 84s 479ms/step - loss: 2.0899 - accuracy: 0.4412 - top-5-accuracy: 0.7570 - val_loss: 2.1193 - val_accuracy: 0.4546 - val_top-5-accuracy: 0.7436
# Epoch 21/50
# 176/176 [==============================] - 84s 477ms/step - loss: 2.0366 - accuracy: 0.4548 - top-5-accuracy: 0.7661 - val_loss: 2.1033 - val_accuracy: 0.4544 - val_top-5-accuracy: 0.7462
# Epoch 22/50
# 176/176 [==============================] - 85s 481ms/step - loss: 1.9900 - accuracy: 0.4632 - top-5-accuracy: 0.7763 - val_loss: 2.0657 - val_accuracy: 0.4606 - val_top-5-accuracy: 0.7586
# Epoch 23/50
# 176/176 [==============================] - 84s 475ms/step - loss: 1.9380 - accuracy: 0.4798 - top-5-accuracy: 0.7855 - val_loss: 2.0338 - val_accuracy: 0.4638 - val_top-5-accuracy: 0.7626
# Epoch 24/50
# 176/176 [==============================] - 84s 478ms/step - loss: 1.9011 - accuracy: 0.4844 - top-5-accuracy: 0.7927 - val_loss: 2.0157 - val_accuracy: 0.4688 - val_top-5-accuracy: 0.7624
# Epoch 25/50
# 176/176 [==============================] - 84s 475ms/step - loss: 1.8479 - accuracy: 0.4944 - top-5-accuracy: 0.8019 - val_loss: 2.0288 - val_accuracy: 0.4724 - val_top-5-accuracy: 0.7636
# Epoch 26/50
# 176/176 [==============================] - 84s 477ms/step - loss: 1.7964 - accuracy: 0.5101 - top-5-accuracy: 0.8105 - val_loss: 2.0160 - val_accuracy: 0.4702 - val_top-5-accuracy: 0.7690
# Epoch 27/50
# 176/176 [==============================] - 84s 479ms/step - loss: 1.7714 - accuracy: 0.5172 - top-5-accuracy: 0.8154 - val_loss: 1.9731 - val_accuracy: 0.4816 - val_top-5-accuracy: 0.7742
# Epoch 28/50
# 176/176 [==============================] - 84s 476ms/step - loss: 1.7236 - accuracy: 0.5250 - top-5-accuracy: 0.8270 - val_loss: 1.9512 - val_accuracy: 0.4874 - val_top-5-accuracy: 0.7798
# Epoch 29/50
# 176/176 [==============================] - 84s 479ms/step - loss: 1.6833 - accuracy: 0.5348 - top-5-accuracy: 0.8309 - val_loss: 1.9465 - val_accuracy: 0.4882 - val_top-5-accuracy: 0.7790
# Epoch 30/50
# 176/176 [==============================] - 84s 475ms/step - loss: 1.6516 - accuracy: 0.5449 - top-5-accuracy: 0.8368 - val_loss: 1.9453 - val_accuracy: 0.4874 - val_top-5-accuracy: 0.7768
# Epoch 31/50
# 176/176 [==============================] - 84s 479ms/step - loss: 1.6241 - accuracy: 0.5488 - top-5-accuracy: 0.8442 - val_loss: 1.9071 - val_accuracy: 0.4986 - val_top-5-accuracy: 0.7830
# Epoch 32/50
# 176/176 [==============================] - 84s 475ms/step - loss: 1.5917 - accuracy: 0.5551 - top-5-accuracy: 0.8496 - val_loss: 1.9190 - val_accuracy: 0.4974 - val_top-5-accuracy: 0.7854
# Epoch 33/50
# 176/176 [==============================] - 84s 480ms/step - loss: 1.5466 - accuracy: 0.5650 - top-5-accuracy: 0.8553 - val_loss: 1.9300 - val_accuracy: 0.4946 - val_top-5-accuracy: 0.7870
# Epoch 34/50
# 176/176 [==============================] - 84s 475ms/step - loss: 1.5215 - accuracy: 0.5729 - top-5-accuracy: 0.8585 - val_loss: 1.9121 - val_accuracy: 0.5024 - val_top-5-accuracy: 0.7860
# Epoch 35/50
# 176/176 [==============================] - 84s 480ms/step - loss: 1.4833 - accuracy: 0.5823 - top-5-accuracy: 0.8664 - val_loss: 1.9317 - val_accuracy: 0.4912 - val_top-5-accuracy: 0.7878
# Epoch 36/50
# 176/176 [==============================] - 84s 476ms/step - loss: 1.4651 - accuracy: 0.5878 - top-5-accuracy: 0.8685 - val_loss: 1.9058 - val_accuracy: 0.5066 - val_top-5-accuracy: 0.7922
# Epoch 37/50
# 176/176 [==============================] - 84s 480ms/step - loss: 1.4345 - accuracy: 0.5947 - top-5-accuracy: 0.8741 - val_loss: 1.8704 - val_accuracy: 0.5146 - val_top-5-accuracy: 0.7954
# Epoch 38/50
# 176/176 [==============================] - 84s 476ms/step - loss: 1.4049 - accuracy: 0.5998 - top-5-accuracy: 0.8800 - val_loss: 1.8658 - val_accuracy: 0.5118 - val_top-5-accuracy: 0.7980
# Epoch 39/50
# 176/176 [==============================] - 84s 478ms/step - loss: 1.3716 - accuracy: 0.6067 - top-5-accuracy: 0.8850 - val_loss: 1.8918 - val_accuracy: 0.5072 - val_top-5-accuracy: 0.7954
# Epoch 40/50
# 176/176 [==============================] - 83s 474ms/step - loss: 1.3604 - accuracy: 0.6118 - top-5-accuracy: 0.8862 - val_loss: 1.8735 - val_accuracy: 0.5158 - val_top-5-accuracy: 0.7948
# Epoch 41/50
# 176/176 [==============================] - 84s 477ms/step - loss: 1.3459 - accuracy: 0.6159 - top-5-accuracy: 0.8880 - val_loss: 1.8858 - val_accuracy: 0.5114 - val_top-5-accuracy: 0.8006
# Epoch 42/50
# 176/176 [==============================] - 83s 473ms/step - loss: 1.3198 - accuracy: 0.6228 - top-5-accuracy: 0.8920 - val_loss: 1.8832 - val_accuracy: 0.5166 - val_top-5-accuracy: 0.7972
# Epoch 43/50
# 176/176 [==============================] - 84s 478ms/step - loss: 1.2863 - accuracy: 0.6326 - top-5-accuracy: 0.8955 - val_loss: 1.9082 - val_accuracy: 0.5148 - val_top-5-accuracy: 0.7960
# Epoch 44/50
# 176/176 [==============================] - 83s 474ms/step - loss: 1.2757 - accuracy: 0.6339 - top-5-accuracy: 0.8984 - val_loss: 1.8722 - val_accuracy: 0.5160 - val_top-5-accuracy: 0.8046
# Epoch 45/50
# 176/176 [==============================] - 84s 480ms/step - loss: 1.2530 - accuracy: 0.6358 - top-5-accuracy: 0.9011 - val_loss: 1.8756 - val_accuracy: 0.5170 - val_top-5-accuracy: 0.8016
# Epoch 46/50
# 176/176 [==============================] - 83s 474ms/step - loss: 1.2235 - accuracy: 0.6460 - top-5-accuracy: 0.9063 - val_loss: 1.9004 - val_accuracy: 0.5184 - val_top-5-accuracy: 0.8044
# Epoch 47/50
# 176/176 [==============================] - 84s 479ms/step - loss: 1.2105 - accuracy: 0.6498 - top-5-accuracy: 0.9096 - val_loss: 1.8912 - val_accuracy: 0.5206 - val_top-5-accuracy: 0.7970
# Epoch 48/50
# 176/176 [==============================] - 83s 474ms/step - loss: 1.1998 - accuracy: 0.6521 - top-5-accuracy: 0.9099 - val_loss: 1.8785 - val_accuracy: 0.5232 - val_top-5-accuracy: 0.8058
# Epoch 49/50
# 176/176 [==============================] - 84s 475ms/step - loss: 1.1791 - accuracy: 0.6542 - top-5-accuracy: 0.9145 - val_loss: 1.8768 - val_accuracy: 0.5246 - val_top-5-accuracy: 0.7978
# Epoch 50/50
# 176/176 [==============================] - 84s 479ms/step - loss: 1.1662 - accuracy: 0.6612 - top-5-accuracy: 0.9153 - val_loss: 1.8698 - val_accuracy: 0.5272 - val_top-5-accuracy: 0.8008
# 40/40 [==============================] - 5s 120ms/step - loss: 1.8229 - accuracy: 0.5318 - top-5-accuracy: 0.8119
# Test accuracy: 53.18%
# Test top 5 accuracy: 81.19%
# Epoch 1/50
# 176/176 [==============================] - 102s 520ms/step - loss: 4.4962 - accuracy: 0.0411 - top-5-accuracy: 0.1507 - val_loss: 3.8896 - val_accuracy: 0.1124 - val_top-5-accuracy: 0.3262
# Epoch 2/50
# 176/176 [==============================] - 89s 507ms/step - loss: 3.9801 - accuracy: 0.0945 - top-5-accuracy: 0.2822 - val_loss: 3.6079 - val_accuracy: 0.1670 - val_top-5-accuracy: 0.4068
# Epoch 3/50
# 176/176 [==============================] - 90s 509ms/step - loss: 3.7544 - accuracy: 0.1256 - top-5-accuracy: 0.3513 - val_loss: 3.4141 - val_accuracy: 0.2066 - val_top-5-accuracy: 0.4650
# Epoch 4/50
# 176/176 [==============================] - 89s 507ms/step - loss: 3.6032 - accuracy: 0.1525 - top-5-accuracy: 0.3938 - val_loss: 3.2620 - val_accuracy: 0.2176 - val_top-5-accuracy: 0.5062
# Epoch 5/50
# 176/176 [==============================] - 90s 509ms/step - loss: 3.4591 - accuracy: 0.1739 - top-5-accuracy: 0.4326 - val_loss: 3.0981 - val_accuracy: 0.2552 - val_top-5-accuracy: 0.5386
# Epoch 6/50
# 176/176 [==============================] - 89s 506ms/step - loss: 3.3309 - accuracy: 0.2008 - top-5-accuracy: 0.4682 - val_loss: 3.0496 - val_accuracy: 0.2628 - val_top-5-accuracy: 0.5624
# Epoch 7/50
# 176/176 [==============================] - 90s 509ms/step - loss: 3.1914 - accuracy: 0.2244 - top-5-accuracy: 0.5033 - val_loss: 2.8654 - val_accuracy: 0.2974 - val_top-5-accuracy: 0.5988
# Epoch 8/50
# 176/176 [==============================] - 89s 506ms/step - loss: 3.0624 - accuracy: 0.2451 - top-5-accuracy: 0.5405 - val_loss: 2.7488 - val_accuracy: 0.3180 - val_top-5-accuracy: 0.6220
# Epoch 9/50
# 176/176 [==============================] - 90s 509ms/step - loss: 2.9206 - accuracy: 0.2726 - top-5-accuracy: 0.5709 - val_loss: 2.6994 - val_accuracy: 0.3166 - val_top-5-accuracy: 0.6142
# Epoch 10/50
# 176/176 [==============================] - 89s 505ms/step - loss: 2.8039 - accuracy: 0.2901 - top-5-accuracy: 0.5980 - val_loss: 2.5104 - val_accuracy: 0.3634 - val_top-5-accuracy: 0.6614
# Epoch 11/50
# 176/176 [==============================] - 90s 509ms/step - loss: 2.6952 - accuracy: 0.3180 - top-5-accuracy: 0.6237 - val_loss: 2.4839 - val_accuracy: 0.3658 - val_top-5-accuracy: 0.6674
# Epoch 12/50
# 176/176 [==============================] - 89s 505ms/step - loss: 2.6058 - accuracy: 0.3344 - top-5-accuracy: 0.6441 - val_loss: 2.4069 - val_accuracy: 0.3832 - val_top-5-accuracy: 0.6852
# Epoch 13/50
# 176/176 [==============================] - 90s 509ms/step - loss: 2.5149 - accuracy: 0.3524 - top-5-accuracy: 0.6643 - val_loss: 2.3000 - val_accuracy: 0.3962 - val_top-5-accuracy: 0.7090
# Epoch 14/50
# 176/176 [==============================] - 89s 505ms/step - loss: 2.4397 - accuracy: 0.3663 - top-5-accuracy: 0.6830 - val_loss: 2.2356 - val_accuracy: 0.4092 - val_top-5-accuracy: 0.7160
# Epoch 15/50
# 176/176 [==============================] - 90s 509ms/step - loss: 2.3512 - accuracy: 0.3861 - top-5-accuracy: 0.7009 - val_loss: 2.2246 - val_accuracy: 0.4236 - val_top-5-accuracy: 0.7236
# Epoch 16/50
# 176/176 [==============================] - 89s 506ms/step - loss: 2.2839 - accuracy: 0.3974 - top-5-accuracy: 0.7140 - val_loss: 2.1419 - val_accuracy: 0.4328 - val_top-5-accuracy: 0.7420
# Epoch 17/50
# 176/176 [==============================] - 90s 511ms/step - loss: 2.2243 - accuracy: 0.4120 - top-5-accuracy: 0.7279 - val_loss: 2.0852 - val_accuracy: 0.4418 - val_top-5-accuracy: 0.7480
# Epoch 18/50
# 176/176 [==============================] - 89s 506ms/step - loss: 2.1539 - accuracy: 0.4267 - top-5-accuracy: 0.7398 - val_loss: 2.0576 - val_accuracy: 0.4470 - val_top-5-accuracy: 0.7602
# Epoch 19/50
# 176/176 [==============================] - 90s 510ms/step - loss: 2.0972 - accuracy: 0.4394 - top-5-accuracy: 0.7542 - val_loss: 2.0446 - val_accuracy: 0.4510 - val_top-5-accuracy: 0.7576
# Epoch 20/50
# 176/176 [==============================] - 89s 507ms/step - loss: 2.0563 - accuracy: 0.4477 - top-5-accuracy: 0.7621 - val_loss: 2.0021 - val_accuracy: 0.4620 - val_top-5-accuracy: 0.7660
# Epoch 21/50
# 176/176 [==============================] - 90s 509ms/step - loss: 1.9950 - accuracy: 0.4642 - top-5-accuracy: 0.7739 - val_loss: 2.0147 - val_accuracy: 0.4618 - val_top-5-accuracy: 0.7630
# Epoch 22/50
# 176/176 [==============================] - 89s 505ms/step - loss: 1.9490 - accuracy: 0.4743 - top-5-accuracy: 0.7822 - val_loss: 1.9757 - val_accuracy: 0.4674 - val_top-5-accuracy: 0.7728
# Epoch 23/50
# 176/176 [==============================] - 89s 506ms/step - loss: 1.9002 - accuracy: 0.4864 - top-5-accuracy: 0.7919 - val_loss: 1.9001 - val_accuracy: 0.4962 - val_top-5-accuracy: 0.7858
# Epoch 24/50
# 176/176 [==============================] - 89s 506ms/step - loss: 1.8640 - accuracy: 0.4938 - top-5-accuracy: 0.7985 - val_loss: 1.9148 - val_accuracy: 0.4930 - val_top-5-accuracy: 0.7808
# Epoch 25/50
# 176/176 [==============================] - 92s 524ms/step - loss: 1.8177 - accuracy: 0.5031 - top-5-accuracy: 0.8096 - val_loss: 1.9202 - val_accuracy: 0.4816 - val_top-5-accuracy: 0.7790
# Epoch 26/50
# 176/176 [==============================] - 90s 510ms/step - loss: 1.7747 - accuracy: 0.5099 - top-5-accuracy: 0.8141 - val_loss: 1.8784 - val_accuracy: 0.4988 - val_top-5-accuracy: 0.7878
# Epoch 27/50
# 176/176 [==============================] - 90s 509ms/step - loss: 1.7412 - accuracy: 0.5215 - top-5-accuracy: 0.8208 - val_loss: 1.8461 - val_accuracy: 0.5072 - val_top-5-accuracy: 0.7978
# Epoch 28/50
# 176/176 [==============================] - 90s 510ms/step - loss: 1.6990 - accuracy: 0.5301 - top-5-accuracy: 0.8295 - val_loss: 1.8879 - val_accuracy: 0.5000 - val_top-5-accuracy: 0.7882
# Epoch 29/50
# 176/176 [==============================] - 90s 509ms/step - loss: 1.6707 - accuracy: 0.5377 - top-5-accuracy: 0.8321 - val_loss: 1.8462 - val_accuracy: 0.5082 - val_top-5-accuracy: 0.7938
# Epoch 30/50
# 176/176 [==============================] - 90s 513ms/step - loss: 1.6248 - accuracy: 0.5482 - top-5-accuracy: 0.8397 - val_loss: 1.8339 - val_accuracy: 0.5098 - val_top-5-accuracy: 0.7998
# Epoch 31/50
# 176/176 [==============================] - 89s 508ms/step - loss: 1.5900 - accuracy: 0.5561 - top-5-accuracy: 0.8465 - val_loss: 1.8016 - val_accuracy: 0.5148 - val_top-5-accuracy: 0.8050
# Epoch 32/50
# 176/176 [==============================] - 90s 512ms/step - loss: 1.5648 - accuracy: 0.5600 - top-5-accuracy: 0.8503 - val_loss: 1.8334 - val_accuracy: 0.5058 - val_top-5-accuracy: 0.7992
# Epoch 33/50
# 176/176 [==============================] - 89s 508ms/step - loss: 1.5529 - accuracy: 0.5646 - top-5-accuracy: 0.8528 - val_loss: 1.8026 - val_accuracy: 0.5132 - val_top-5-accuracy: 0.8032
# Epoch 34/50
# 176/176 [==============================] - 90s 512ms/step - loss: 1.5131 - accuracy: 0.5751 - top-5-accuracy: 0.8589 - val_loss: 1.7825 - val_accuracy: 0.5290 - val_top-5-accuracy: 0.8082
# Epoch 35/50
# 176/176 [==============================] - 89s 507ms/step - loss: 1.4817 - accuracy: 0.5820 - top-5-accuracy: 0.8666 - val_loss: 1.7876 - val_accuracy: 0.5218 - val_top-5-accuracy: 0.8060
# Epoch 36/50
# 176/176 [==============================] - 90s 513ms/step - loss: 1.4532 - accuracy: 0.5873 - top-5-accuracy: 0.8695 - val_loss: 1.8088 - val_accuracy: 0.5146 - val_top-5-accuracy: 0.8016
# Epoch 37/50
# 176/176 [==============================] - 90s 509ms/step - loss: 1.4325 - accuracy: 0.5942 - top-5-accuracy: 0.8731 - val_loss: 1.7920 - val_accuracy: 0.5242 - val_top-5-accuracy: 0.8028
# Epoch 38/50
# 176/176 [==============================] - 90s 514ms/step - loss: 1.4108 - accuracy: 0.5980 - top-5-accuracy: 0.8775 - val_loss: 1.7708 - val_accuracy: 0.5224 - val_top-5-accuracy: 0.8112
# Epoch 39/50
# 176/176 [==============================] - 89s 508ms/step - loss: 1.3887 - accuracy: 0.6053 - top-5-accuracy: 0.8799 - val_loss: 1.7836 - val_accuracy: 0.5270 - val_top-5-accuracy: 0.8146
# Epoch 40/50
# 176/176 [==============================] - 90s 513ms/step - loss: 1.3771 - accuracy: 0.6072 - top-5-accuracy: 0.8822 - val_loss: 1.7869 - val_accuracy: 0.5308 - val_top-5-accuracy: 0.8054
# Epoch 41/50
# 176/176 [==============================] - 90s 510ms/step - loss: 1.3351 - accuracy: 0.6180 - top-5-accuracy: 0.8898 - val_loss: 1.7938 - val_accuracy: 0.5190 - val_top-5-accuracy: 0.8060
# Epoch 42/50
# 176/176 [==============================] - 90s 514ms/step - loss: 1.3200 - accuracy: 0.6217 - top-5-accuracy: 0.8905 - val_loss: 1.7476 - val_accuracy: 0.5386 - val_top-5-accuracy: 0.8170
# Epoch 43/50
# 176/176 [==============================] - 90s 510ms/step - loss: 1.3074 - accuracy: 0.6255 - top-5-accuracy: 0.8925 - val_loss: 1.7689 - val_accuracy: 0.5396 - val_top-5-accuracy: 0.8162
# Epoch 44/50
# 176/176 [==============================] - 90s 514ms/step - loss: 1.2781 - accuracy: 0.6326 - top-5-accuracy: 0.8960 - val_loss: 1.7261 - val_accuracy: 0.5482 - val_top-5-accuracy: 0.8176
# Epoch 45/50
# 176/176 [==============================] - 90s 510ms/step - loss: 1.2609 - accuracy: 0.6392 - top-5-accuracy: 0.9006 - val_loss: 1.7390 - val_accuracy: 0.5392 - val_top-5-accuracy: 0.8222
# Epoch 46/50
# 176/176 [==============================] - 90s 513ms/step - loss: 1.2523 - accuracy: 0.6386 - top-5-accuracy: 0.9018 - val_loss: 1.7306 - val_accuracy: 0.5406 - val_top-5-accuracy: 0.8206
# Epoch 47/50
# 176/176 [==============================] - 90s 510ms/step - loss: 1.2187 - accuracy: 0.6503 - top-5-accuracy: 0.9044 - val_loss: 1.7251 - val_accuracy: 0.5506 - val_top-5-accuracy: 0.8252
# Epoch 48/50
# 176/176 [==============================] - 90s 514ms/step - loss: 1.2104 - accuracy: 0.6483 - top-5-accuracy: 0.9069 - val_loss: 1.7466 - val_accuracy: 0.5408 - val_top-5-accuracy: 0.8172
# Epoch 49/50
# 176/176 [==============================] - 90s 510ms/step - loss: 1.1895 - accuracy: 0.6552 - top-5-accuracy: 0.9101 - val_loss: 1.7228 - val_accuracy: 0.5556 - val_top-5-accuracy: 0.8296
# Epoch 50/50
# 176/176 [==============================] - 91s 515ms/step - loss: 1.1822 - accuracy: 0.6560 - top-5-accuracy: 0.9121 - val_loss: 1.7215 - val_accuracy: 0.5452 - val_top-5-accuracy: 0.8242
# 40/40 [==============================] - 6s 137ms/step - loss: 1.6645 - accuracy: 0.5626 - top-5-accuracy: 0.8292
# Test accuracy: 56.26%
# Test top 5 accuracy: 82.92%

# %% [markdown]
# # Final Notes
#
# With the help of Shifted Patch Tokenization and Locality Self Attention,
# we were able to get ~**3-4%** top-1 accuracy gains on CIFAR100.
#
# The ideas on Shifted Patch Tokenization and Locality Self Attention
# are very intuitive and easy to implement. The authors also ablates of
# different shifting strategies for Shifted Patch Tokenization in the
# supplementary of the paper.
#
# I would like to thank [Jarvislabs.ai](https://jarvislabs.ai/) for
# generously helping with GPU credits.
#
# You can use the trained model hosted on [Hugging Face Hub](https://huggingface.co/keras-io/vit_small_ds_v2) and try the demo on [Hugging Face Spaces](https://huggingface.co/spaces/keras-io/vit-small-ds).

# %%
vit.save('./gdrive/MyDrive/GNR638/vit_model1_CIFAR100')
vit_sl.save('./gdrive/MyDrive/GNR638/vitsl_model1_CIFAR100')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.normalization.layer_normalization.LayerNormalization object at 0x7f166ae5cb90>, because it is not built.
# WARNING:absl:Found untraced functions such as reshape_2_layer_call_fn, reshape_2_layer_call_and_return_conditional_losses, dense_2_layer_call_fn, dense_2_layer_call_and_return_conditional_losses, embedding_layer_call_fn while saving (showing 5 of 102). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as reshape_3_layer_call_fn, reshape_3_layer_call_and_return_conditional_losses, dense_22_layer_call_fn, dense_22_layer_call_and_return_conditional_losses, layer_normalization_20_layer_call_fn while saving (showing 5 of 104). These functions will not be directly callable after loading.

# %%
vit_load = tf.keras.models.load_model('./gdrive/MyDrive/GNR638/vitsl_model1_CIFAR100')

# %%
n = y_test.shape[0]
x_pred = vit_load.predict(x_test[0:n])
# Out:
# 313/313 [==============================] - 14s 25ms/step

# %%
pred = np.argmax(x_pred,axis=1)
actual = y_test[0:n].flatten()
accuracy = np.sum(pred==actual)*100/n
accuracy
# Out:
# 56.26
